# %%
import matplotlib.pyplot as plt

# Algorithms and their corresponding accuracy values (modify these as per your data)
algorithms = ['Random Forest', 'Stacking Classifier', 'Voting Classifier', 'Decision Tree', 'Logistic Regression']
accuracy = [85, 80, 85, 85, 64]  # Modify these accuracy values

# Create bar chart
plt.figure(figsize=(10,6))
plt.bar(algorithms, accuracy, color='skyblue')

# Adding title and labels
plt.title('Machine Learning Algorithm Comparison')
plt.xlabel('Algorithms')
plt.ylabel('Accuracy (%)')

# Show the plot
plt.show()
